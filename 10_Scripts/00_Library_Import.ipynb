# %%
# %pip install --upgrade pip
# %pip install pandas numpy matplotlib

# %%
# %pip install --upgrade setuptools
# %pip install autoviz
# Out:
# Collecting setuptools
#   Using cached setuptools-80.8.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-80.8.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools
# Successfully installed setuptools-80.8.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: autoviz in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: wordcloud in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.9.4)
# Requirement already satisfied: emoji in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (2.14.1)
# Requirement already satisfied: pyamg in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (5.2.1)
# Requirement already satisfied: scikit-learn in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (0.14.4)
# Requirement already satisfied: nltk in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (2025.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (4.13.2)
# Requirement already satisfied: pandas-dq>=1.29 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (2.2.6)
# Requirement already satisfied: hvplot>=0.9.2 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (0.11.3)
# Requirement already satisfied: holoviews>=1.16.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.20.2)
# Requirement already satisfied: panel>=1.4.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (1.7.0)
# Requirement already satisfied: pandas>=2.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (2.2.3)
# Requirement already satisfied: matplotlib>3.7.4 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (3.10.3)
# Requirement already satisfied: seaborn>0.12.2 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: scipy in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from xgboost<1.7,>=0.82->autoviz) (1.15.3)
# Requirement already satisfied: bokeh>=3.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.7.3)
# Requirement already satisfied: colorcet in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from holoviews>=1.16.0->autoviz) (25.0)
# Requirement already satisfied: param<3.0,>=2.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.2.0)
# Requirement already satisfied: pyviz-comms>=2.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.4)
# Requirement already satisfied: Jinja2>=2.9 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.3.2)
# Requirement already satisfied: narwhals>=1.13 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.40.0)
# Requirement already satisfied: pillow>=7.1.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (11.2.1)
# Requirement already satisfied: PyYAML>=3.10 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.5)
# Requirement already satisfied: xyzservices>=2021.09.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.3)
# Requirement already satisfied: markdown in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (3.8)
# Requirement already satisfied: markdown-it-py in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (0.4.2)
# Requirement already satisfied: requests in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: six>=1.5 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from scikit-learn->autoviz) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: webencodings in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: click in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from nltk->autoviz) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: colorama in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in d:\purwadhikabackup\capstoneproject\modultiga\electronic-sales-clustering\venv\lib\site-packages (from statsmodels->autoviz) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install category_encoders
# %pip install gap-stat
# Out:
# Collecting gap-stat
#   Downloading gap-stat-2.0.3.tar.gz (17 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [62 lines of output]
#       C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\wheel\metadata.py:16: SyntaxWarning: invalid escape sequence '\s'
#         EXTRA_RE = re.compile("""^(?P<package>.*?)(;\s*(?P<condition>.*?)(extra == '(?P<extra>.*?)')?)$""")
#       running dist_info
#       creating C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info
#       writing C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\PKG-INFO
#       writing dependency_links to C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\dependency_links.txt
#       writing requirements to C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\requires.txt
#       writing top-level names to C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\top_level.txt
#       writing manifest file 'C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\SOURCES.txt'
#       reading manifest file 'C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE-MIT'
#       writing manifest file 'C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat.egg-info\SOURCES.txt'
#       creating 'C:\Users\mirur\AppData\Local\Temp\pip-modern-metadata-yann798e\gap_stat-2.0.3.dist-info'
#       Traceback (most recent call last):
#         File "d:\PurwadhikaBackup\capstoneproject\modultiga\electronic-sales-clustering\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "d:\PurwadhikaBackup\capstoneproject\modultiga\electronic-sales-clustering\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "d:\PurwadhikaBackup\capstoneproject\modultiga\electronic-sales-clustering\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 175, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\build_meta.py", line 374, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 15, in <module>
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 202, in run_commands
#           dist.run_commands()
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\command\dist_info.py", line 99, in run
#           bdist_wheel = self.get_finalized_command('bdist_wheel')
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 333, in get_finalized_command
#           cmd_obj = self.distribution.get_command_obj(command, create)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 884, in get_command_obj
#           klass = self.get_command_class(command)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\dist.py", line 840, in get_command_class
#           from .command.bdist_wheel import bdist_wheel
#         File "C:\Users\mirur\AppData\Local\Temp\pip-build-env-uc39gmno\overlay\Lib\site-packages\setuptools\command\bdist_wheel.py", line 23, in <module>
#           from wheel.wheelfile import WheelFile
#       ModuleNotFoundError: No module named 'wheel.wheelfile'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# autoviz                 0.1.905
# bleach                  6.2.0
# bokeh                   3.7.3
# category_encoders       2.8.1
# certifi                 2025.4.26
# charset-normalizer      3.4.2
# click                   8.2.1
# colorama                0.4.6
# colorcet                3.1.0
# comm                    0.2.2
# contourpy               1.3.2
# cycler                  0.12.1
# debugpy                 1.8.14
# decorator               5.2.1
# emoji                   2.14.1
# executing               2.2.0
# fonttools               4.58.0
# fsspec                  2025.5.0
# holoviews               1.20.2
# hvplot                  0.11.3
# idna                    3.10
# ipykernel               6.29.5
# ipython                 9.2.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# Jinja2                  3.1.6
# joblib                  1.5.0
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# kiwisolver              1.4.8
# linkify-it-py           2.0.3
# Markdown                3.8
# markdown-it-py          3.0.0
# MarkupSafe              3.0.2
# matplotlib              3.10.3
# matplotlib-inline       0.1.7
# mdit-py-plugins         0.4.2
# mdurl                   0.1.2
# narwhals                1.40.0
# nest-asyncio            1.6.0
# nltk                    3.9.1
# numpy                   2.2.6
# packaging               25.0
# pandas                  2.2.3
# pandas-dq               1.29
# panel                   1.7.0
# param                   2.2.0
# parso                   0.8.4
# patsy                   1.0.1
# pillow                  11.2.1
# pip                     25.1.1
# platformdirs            4.3.8
# prompt_toolkit          3.0.51
# psutil                  7.0.0
# pure_eval               0.2.3
# pyamg                   5.2.1
# Pygments                2.19.1
# pyparsing               3.2.3
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pyviz_comms             3.0.4
# pywin32                 310
# PyYAML                  6.0.2
# pyzmq                   26.4.0
# regex                   2024.11.6
# requests                2.32.3
# scikit-learn            1.6.1
# scipy                   1.15.3
# seaborn                 0.13.2
# setuptools              80.8.0
# six                     1.17.0
# stack-data              0.6.3
# statsmodels             0.14.4
# textblob                0.19.0
# threadpoolctl           3.6.0
# tornado                 6.5
# tqdm                    4.67.1
# traitlets               5.14.3
# typing_extensions       4.13.2
# tzdata                  2025.2
# uc-micro-py             1.0.3
# urllib3                 2.4.0
# wcwidth                 0.2.13
# webencodings            0.5.1
# wordcloud               1.9.4
# xgboost                 1.6.2
# xlrd                    2.0.1
# xyzservices             2025.4.0
# Note: you may need to restart the kernel to use updated packages.
