# %% [markdown]
# 1. Memuat Data dan Library yang Diperlukan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# %matplotlib inline

# %%
data = pd.read_csv('../00_Data/vgsales.csv')
data.head()
# Out:
#    Rank            Name           Platform   Year      Genre     Publisher  \
# 0    1                 Wii Sports    Wii    2006.0        Sports  Nintendo
# 1    2          Super Mario Bros.    NES    1985.0      Platform  Nintendo
# 2    3             Mario Kart Wii    Wii    2008.0        Racing  Nintendo
# 3    4          Wii Sports Resort    Wii    2009.0        Sports  Nintendo
# 4    5   Pokemon Red/Pokemon Blue     GB    1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0    41.49     29.02      3.77      8.46          82.74
# 1    29.08      3.58      6.81      0.77          40.24
# 2    15.85     12.88      3.79      3.31          35.82
# 3    15.75     11.01      3.28      2.96          33.00
# 4    11.27      8.89     10.22      1.00          31.37

# %% [markdown]
# 2. Analisis Dasar Dataset

# %%
AV = AutoViz_Class()

# %%
AV.AutoViz(filename='Electronic Sales Report', dfte=data)
plt.show()
# Out:
# Shape of your Data Set loaded: (16598, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Rank']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_568f2_row0_col0, #T_568f2_row0_col2, #T_568f2_row0_col3, #T_568f2_row0_col4, #T_568f2_row0_col5, #T_568f2_row1_col0, #T_568f2_row1_col2, #T_568f2_row1_col3, #T_568f2_row1_col4, #T_568f2_row1_col5, #T_568f2_row2_col0, #T_568f2_row2_col2, #T_568f2_row2_col3, #T_568f2_row2_col4, #T_568f2_row2_col5, #T_568f2_row3_col0, #T_568f2_row3_col2, #T_568f2_row3_col3, #T_568f2_row3_col4, #T_568f2_row3_col5, #T_568f2_row4_col0, #T_568f2_row4_col2, #T_568f2_row4_col3, #T_568f2_row4_col4, #T_568f2_row4_col5, #T_568f2_row5_col0, #T_568f2_row5_col2, #T_568f2_row5_col3, #T_568f2_row5_col4, #T_568f2_row5_col5, #T_568f2_row6_col0, #T_568f2_row6_col2, #T_568f2_row6_col3, #T_568f2_row6_col4, #T_568f2_row6_col5, #T_568f2_row7_col0, #T_568f2_row7_col2, #T_568f2_row7_col3, #T_568f2_row7_col4, #T_568f2_row7_col5, #T_568f2_row8_col0, #T_568f2_row8_col2, #T_568f2_row8_col3, #T_568f2_row8_col4, #T_568f2_row8_col5, #T_568f2_row9_col0, #T_568f2_row9_col2, #T_568f2_row9_col3, #T_568f2_row9_col4, #T_568f2_row9_col5, #T_568f2_row10_col0, #T_568f2_row10_col2, #T_568f2_row10_col3, #T_568f2_row10_col4, #T_568f2_row10_col5 {
#   font-family: Segoe UI;
# }
# #T_568f2_row0_col1, #T_568f2_row1_col1, #T_568f2_row2_col1, #T_568f2_row4_col1, #T_568f2_row6_col1, #T_568f2_row7_col1, #T_568f2_row8_col1, #T_568f2_row9_col1, #T_568f2_row10_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_568f2_row3_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_568f2_row5_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_568f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_568f2_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_568f2_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_568f2_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_568f2_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_568f2_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_568f2_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_568f2_level0_row0" class="row_heading level0 row0" >Rank</th>
#       <td id="T_568f2_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_568f2_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_568f2_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_568f2_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_568f2_row0_col4" class="data row0 col4" >16600.000000</td>
#       <td id="T_568f2_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row1" class="row_heading level0 row1" >Name</th>
#       <td id="T_568f2_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_568f2_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_568f2_row1_col2" class="data row1 col2" >69</td>
#       <td id="T_568f2_row1_col3" class="data row1 col3" ></td>
#       <td id="T_568f2_row1_col4" class="data row1 col4" ></td>
#       <td id="T_568f2_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row2" class="row_heading level0 row2" >Platform</th>
#       <td id="T_568f2_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_568f2_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_568f2_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_568f2_row2_col3" class="data row2 col3" ></td>
#       <td id="T_568f2_row2_col4" class="data row2 col4" ></td>
#       <td id="T_568f2_row2_col5" class="data row2 col5" >13 rare categories: Too many to list. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row3" class="row_heading level0 row3" >Year</th>
#       <td id="T_568f2_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_568f2_row3_col1" class="data row3 col1" >1.632727</td>
#       <td id="T_568f2_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_568f2_row3_col3" class="data row3 col3" >1980.000000</td>
#       <td id="T_568f2_row3_col4" class="data row3 col4" >2020.000000</td>
#       <td id="T_568f2_row3_col5" class="data row3 col5" >271 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 305 outliers greater than upper bound (2020.50) or lower than lower bound(1992.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row4" class="row_heading level0 row4" >Genre</th>
#       <td id="T_568f2_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_568f2_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_568f2_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_568f2_row4_col3" class="data row4 col3" ></td>
#       <td id="T_568f2_row4_col4" class="data row4 col4" ></td>
#       <td id="T_568f2_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row5" class="row_heading level0 row5" >Publisher</th>
#       <td id="T_568f2_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_568f2_row5_col1" class="data row5 col1" >0.349440</td>
#       <td id="T_568f2_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_568f2_row5_col3" class="data row5 col3" ></td>
#       <td id="T_568f2_row5_col4" class="data row5 col4" ></td>
#       <td id="T_568f2_row5_col5" class="data row5 col5" >58 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,, Possible high cardinality column with 578 unique values: Use hash encoding or text embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row6" class="row_heading level0 row6" >NA_Sales</th>
#       <td id="T_568f2_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_568f2_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_568f2_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_568f2_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_568f2_row6_col4" class="data row6 col4" >41.490000</td>
#       <td id="T_568f2_row6_col5" class="data row6 col5" >Column has 1681 outliers greater than upper bound (0.60) or lower than lower bound(-0.36). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row7" class="row_heading level0 row7" >EU_Sales</th>
#       <td id="T_568f2_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_568f2_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_568f2_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_568f2_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_568f2_row7_col4" class="data row7 col4" >29.020000</td>
#       <td id="T_568f2_row7_col5" class="data row7 col5" >Column has 2081 outliers greater than upper bound (0.28) or lower than lower bound(-0.17). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row8" class="row_heading level0 row8" >JP_Sales</th>
#       <td id="T_568f2_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_568f2_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_568f2_row8_col2" class="data row8 col2" >NA</td>
#       <td id="T_568f2_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_568f2_row8_col4" class="data row8 col4" >10.220000</td>
#       <td id="T_568f2_row8_col5" class="data row8 col5" >Column has 2425 outliers greater than upper bound (0.10) or lower than lower bound(-0.06). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_568f2_level0_row9" class="row_heading level0 row9" >Other_Sales</th>
#       <td id="T_568f2_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_568f2_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id=
# Number of All Scatter Plots = 21
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\mirur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# All Plots done
# Time to run AutoViz = 27 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
