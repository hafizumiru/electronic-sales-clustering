# %% [markdown]
# 1. Memuat Data dan Library yang Diperlukan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from autoviz.AutoViz_Class import AutoViz_Class

# %%
# %matplotlib inline

# %%
data = pd.read_csv('../00_Data/electronic_sales_prepared.csv')
data.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type   SKU     Rating  \
# 0     1000      53   Male         No       Smartphone   SKU1004     2
# 1     1000      53   Male         No           Tablet   SKU1002     3
# 2     1002      41   Male         No           Laptop   SKU1005     3
# 3     1002      41   Male        Yes       Smartphone   SKU1004     2
# 4     1003      75   Male        Yes       Smartphone   SKU1001     5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0   Cancelled    Credit Card     5538.33      791.19        7
# 1   Completed         Paypal      741.09      247.03        3
# 2   Completed    Credit Card     1855.84      463.96        4
# 3   Completed           Cash     3164.76      791.19        4
# 4   Completed           Cash       41.50       20.75        2
#
#   Shipping Type       Add-ons Purchased         Add-on Total  Purchase_Day  \
# 0     Standard   Accessory,Accessory,Accessory      40.21          20
# 1    Overnight                    Impulse Item      26.09          20
# 2      Express                       No Addons       0.00          17
# 3    Overnight       Impulse Item,Impulse Item      60.16           9
# 4      Express                       Accessory      35.56          21
#
#    Purchase_Month  Purchase_Year  Accessory_count  Impulse Item_count  \
# 0         3            2024              3                  0
# 1         4            2024              0                  1
# 2        10            2023              0                  0
# 3         8            2024              0                  2
# 4         5            2024              1                  0
#
#    No Addons_count  Extended Warranty_count
# 0         0                    0
# 1         0                    0
# 2         1                    0
# 3         0                    0
# 4         0                    0

# %% [markdown]
# 2. Analisis Dasar Dataset

# %%
AV = AutoViz_Class()

# %%
AV.AutoViz(filename='Electronic Sales Report', dfte=data)
plt.show()
# Out:
# Shape of your Data Set loaded: (19999, 22)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  9
#     Number of String-Categorical Columns =  5
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     22 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_87627_row0_col0, #T_87627_row0_col2, #T_87627_row0_col3, #T_87627_row0_col4, #T_87627_row0_col5, #T_87627_row1_col0, #T_87627_row1_col2, #T_87627_row1_col3, #T_87627_row1_col4, #T_87627_row1_col5, #T_87627_row2_col0, #T_87627_row2_col2, #T_87627_row2_col3, #T_87627_row2_col4, #T_87627_row2_col5, #T_87627_row3_col0, #T_87627_row3_col2, #T_87627_row3_col3, #T_87627_row3_col4, #T_87627_row3_col5, #T_87627_row4_col0, #T_87627_row4_col2, #T_87627_row4_col3, #T_87627_row4_col4, #T_87627_row4_col5, #T_87627_row5_col0, #T_87627_row5_col2, #T_87627_row5_col3, #T_87627_row5_col4, #T_87627_row5_col5, #T_87627_row6_col0, #T_87627_row6_col2, #T_87627_row6_col3, #T_87627_row6_col4, #T_87627_row6_col5, #T_87627_row7_col0, #T_87627_row7_col2, #T_87627_row7_col3, #T_87627_row7_col4, #T_87627_row7_col5, #T_87627_row8_col0, #T_87627_row8_col2, #T_87627_row8_col3, #T_87627_row8_col4, #T_87627_row8_col5, #T_87627_row9_col0, #T_87627_row9_col2, #T_87627_row9_col3, #T_87627_row9_col4, #T_87627_row9_col5, #T_87627_row10_col0, #T_87627_row10_col2, #T_87627_row10_col3, #T_87627_row10_col4, #T_87627_row10_col5, #T_87627_row11_col0, #T_87627_row11_col2, #T_87627_row11_col3, #T_87627_row11_col4, #T_87627_row11_col5, #T_87627_row12_col0, #T_87627_row12_col2, #T_87627_row12_col3, #T_87627_row12_col4, #T_87627_row12_col5, #T_87627_row13_col0, #T_87627_row13_col2, #T_87627_row13_col3, #T_87627_row13_col4, #T_87627_row13_col5, #T_87627_row14_col0, #T_87627_row14_col2, #T_87627_row14_col3, #T_87627_row14_col4, #T_87627_row14_col5, #T_87627_row15_col0, #T_87627_row15_col2, #T_87627_row15_col3, #T_87627_row15_col4, #T_87627_row15_col5, #T_87627_row16_col0, #T_87627_row16_col2, #T_87627_row16_col3, #T_87627_row16_col4, #T_87627_row16_col5, #T_87627_row17_col0, #T_87627_row17_col2, #T_87627_row17_col3, #T_87627_row17_col4, #T_87627_row17_col5, #T_87627_row18_col0, #T_87627_row18_col2, #T_87627_row18_col3, #T_87627_row18_col4, #T_87627_row18_col5, #T_87627_row19_col0, #T_87627_row19_col2, #T_87627_row19_col3, #T_87627_row19_col4, #T_87627_row19_col5, #T_87627_row20_col0, #T_87627_row20_col2, #T_87627_row20_col3, #T_87627_row20_col4, #T_87627_row20_col5, #T_87627_row21_col0, #T_87627_row21_col2, #T_87627_row21_col3, #T_87627_row21_col4, #T_87627_row21_col5 {
#   font-family: Segoe UI;
# }
# #T_87627_row0_col1, #T_87627_row1_col1, #T_87627_row2_col1, #T_87627_row3_col1, #T_87627_row4_col1, #T_87627_row5_col1, #T_87627_row6_col1, #T_87627_row7_col1, #T_87627_row8_col1, #T_87627_row9_col1, #T_87627_row10_col1, #T_87627_row11_col1, #T_87627_row12_col1, #T_87627_row13_col1, #T_87627_row14_col1, #T_87627_row15_col1, #T_87627_row16_col1, #T_87627_row17_col1, #T_87627_row18_col1, #T_87627_row19_col1, #T_87627_row20_col1, #T_87627_row21_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_87627">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87627_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_87627_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_87627_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_87627_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_87627_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_87627_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87627_level0_row0" class="row_heading level0 row0" >Customer ID</th>
#       <td id="T_87627_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_87627_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_87627_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_87627_row0_col3" class="data row0 col3" >1000.000000</td>
#       <td id="T_87627_row0_col4" class="data row0 col4" >19997.000000</td>
#       <td id="T_87627_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_87627_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_87627_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_87627_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_87627_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_87627_row1_col4" class="data row1 col4" >80.000000</td>
#       <td id="T_87627_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row2" class="row_heading level0 row2" >Gender</th>
#       <td id="T_87627_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_87627_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_87627_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_87627_row2_col3" class="data row2 col3" ></td>
#       <td id="T_87627_row2_col4" class="data row2 col4" ></td>
#       <td id="T_87627_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row3" class="row_heading level0 row3" >Loyalty Member</th>
#       <td id="T_87627_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_87627_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_87627_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_87627_row3_col3" class="data row3 col3" ></td>
#       <td id="T_87627_row3_col4" class="data row3 col4" ></td>
#       <td id="T_87627_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row4" class="row_heading level0 row4" >Product Type</th>
#       <td id="T_87627_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_87627_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_87627_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_87627_row4_col3" class="data row4 col3" ></td>
#       <td id="T_87627_row4_col4" class="data row4 col4" ></td>
#       <td id="T_87627_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row5" class="row_heading level0 row5" >SKU</th>
#       <td id="T_87627_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_87627_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_87627_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_87627_row5_col3" class="data row5 col3" ></td>
#       <td id="T_87627_row5_col4" class="data row5 col4" ></td>
#       <td id="T_87627_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row6" class="row_heading level0 row6" >Rating</th>
#       <td id="T_87627_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_87627_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_87627_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_87627_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_87627_row6_col4" class="data row6 col4" >5.000000</td>
#       <td id="T_87627_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row7" class="row_heading level0 row7" >Order Status</th>
#       <td id="T_87627_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_87627_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_87627_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_87627_row7_col3" class="data row7 col3" ></td>
#       <td id="T_87627_row7_col4" class="data row7 col4" ></td>
#       <td id="T_87627_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_87627_level0_row8" class="row_heading level0 row8" >Payment Method</th>
#       <td id="T_87627_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_87627_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_87627_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_87627_row8_col3" class="data row8 col3" ></td>
#       <td id="T_87627_row8_col4" class="data row8 col4" ></td>
#       <td id="T_8762
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz = 12 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
